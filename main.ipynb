# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
#your code here
    if a > b :
        return a
    else:
        return b

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.248s
#
# OK

# %%
#your code here
greater_num = greater(23,54)
print(greater_num)
# Out:
# 54

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
#your code here
def greatest(a):
    max_num = 0
    for i in a:
        if i > max_num:
            max_num = i
    return max_num

# %%
input_list = input("Enter the list")
b = [int(i.strip()) for i in input_list.split(",")]
#input_list = [1,3,4,5,6,8,2,3]
b1 = greatest((b))
print(b1)
# Out:
# 6

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.114s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
#your code here
    sum1 = 0
    for i in lst:
        sum1 += i
    return sum1

# %%
in_list = input("Enter the numbers with comma: ")
clean_list = []
for i in in_list.split(','):
    i = i.strip()
    digits_only = int(''.join(ch for ch in i if ch.isdigit())) 
    clean_list.append(digits_only)
total = sum_all(clean_list) 
print(total)
# Out:
# 291

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.111s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
#your code here
    mult_all = 1
    for i in lst:
        mult_all *= i
    return mult_all

# %%
in_list1 = input("Enter the numbers with comma: ")
input_num = [int(i) for i in in_list1.split(',')]
multiples = mult_all(input_num)
print(input_num)
print(multiples)
# Out:
# [34, 56, 78]
# 148512

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.103s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper = "*"):
#your code here
    if oper == "*":  
        return mult_all(arr)
    else:
        return sum_all(arr)

# %%
input_list = input("Enter the numbers with commas: ")
operation = input("enter the operaion '*' or '+'")
clean_list = [int(i.strip()) for i in input_list.split(',')]
output = oper_all(clean_list,operation)
print(f"{clean_list} {operation}")
print(output)
# Out:
# [32, 45, 67, 89] *
# 8586720

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.113s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    fact = 1
#your code here
    while n != 0:
         fact *= n
         n = n-1
    return fact

# %%
input_number = int(input("Enter the number: "))
output = factorial(input_number)
print(f"factorial of {input_number} is {output}")
# Out:
# factorial of 6 is 720

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.107s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):
    unique_list = []
    for i in lst_un:
        if i not in unique_list:
            unique_list.append(i)
    return unique_list        


#your code here

# %%
input_list = input("Enter the numbers with commas: ")
clean_in = [int(i.strip()) for i in input_list.split(',')]
output = unique(clean_in)
print(f"{clean_in} is transformed to {output}")
# Out:
# [34, 45, 6, 789] is transformed to [34, 45, 6, 789]

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.327s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
 #your code here
    mode_dict = {}
    for i in arr:
        if i not in mode_dict.keys():
            mode_dict[i] = 1
        else:
            mode_dict[i] += 1
    max_freq = 0
    mode_val = None
    for key, value in mode_dict.items():
        if value > max_freq:
            max_freq = value
            mode_val = key
    return mode_val, max_freq

# %%
input_list = input("Enter the numbers with commas: ")
clean_in = [int(i.strip()) for i in input_list.split(',')]
output = mode_counter(clean_in)
print(f"{clean_in} is transformed to {output}")
# Out:
# [2, 3, 45, 6] is transformed to (2, 1)

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# F
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ...
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\Denish\Desktop\AI\Labs\lab-functions-en\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: (22, 54) != 22 : Should be 22
#
# ...
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\Denish\Desktop\AI\Labs\lab-functions-en\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: (17, 54) != 17 : Should be 17
#
# ...
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ...

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(list_sd):
#your code here
    total = 0
    count = 0
    for i in list_sd:
        total += i
        count += 1
    mean = total / count

    max_sd = 0
    for i in list_sd:
        sd = i - mean
        if sd < 0:
            sd = -sd
        if sd > max_sd:
            max_sd = sd
    return max_sd

# %%
input_list = input("Enter the numbers with commas: ")
clean_in = [int(i.strip()) for i in input_list.split(',')]
output = st_dev(clean_in)
print(f"for {clean_in} max SD is {output}")
# Out:
# for [3, 4, 56, 78] max SD is 42.75

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ...
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\Denish\Desktop\AI\Labs\lab-functions-en\mod\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 1134.8804347826087 != 541.0194862000449 within 5 delta (593.8609485825639 difference) : Should be 541.0194862000449
#
# ...
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\Denish\Desktop\AI\Labs\lab-functions-en\mod\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# ...

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
import string as str_module
def pangram(string):
#your code here
    alphabet_set = set(str_module.ascii_lowercase)
    letter_set = set()
    for i in string.lower():
        if i.isalpha():
            letter_set.add(i)
    return letter_set == alphabet_set

# %%
print(pangram("The quick brown fox jumps over the lazy dog"))  
print(pangram("Hello World"))
# Out:
# True
# False

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.048s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    word = []
    current_word = ""
    for i in string:
        if i == ",":
            word.append(current_word)
            current_word = ""
        
        else:
           current_word += i
    word.append(current_word)   
    word1 = sorted(word) 
    return word1

# %%
print(sort_alpha("cat,bear,lion,dog,horse"))
# Out:
# ['bear', 'cat', 'dog', 'horse', 'lion']

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# FFFFFFFFFFFF
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ...
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\Denish\Desktop\AI\Labs\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['bekauaisnv', 'boadnmwnr', 'cztjmulqjm',[167 chars]gba'] != 'bekauaisnv,boadnmwnr,cztjmulqjm,fswyvpok[111 chars]jgba' : Should be bekauaisnv,boadnmwnr,cztjmulqjm,fswyvpokhz,gywvta,ihjw,iqvofxlnja,jqnn,lwbskbmhsi,mpapxqszoh,mxcphcugx,ogwgn,ooqulq,qaeez,tbhr,tzvrffp,uvebdp,wgzviy,zkjgba
#
# ...
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
# ...

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
#your code here
    sum = 0
    has_lower = False
    has_upper = False
    has_digit = False
    has_special = False
    special_characters = "!@#$%^&*()-_+=[]{}|\\:;\"'<>,.?/"
    if len(password) < 8:
        return False
    for i in password: 
            if i.islower():
                has_lower = True
            elif i.isupper():
                has_upper = True
            elif i.isdigit():
                has_digit = True
            elif i in special_characters:
                has_special = True
                  
    return has_lower and has_upper and has_digit and has_special

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.135s
#
# OK

# %%
print(check_pass("Sd1@234tf"))
# Out:
# True
